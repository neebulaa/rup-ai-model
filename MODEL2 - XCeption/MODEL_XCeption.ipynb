# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
# Out:
# WARNING:tensorflow:From c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### **DATA PREPARATION**

# %%
dataset_dir = r'C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\datasets'

# Prepare lists to store file paths and labels
filepaths = []
labels = []

# Go through each class folder
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_path):
        for filename in os.listdir(class_path):
            if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # Filter image files
                file_path = os.path.join(class_path, filename)
                filepaths.append(file_path)
                labels.append(class_name)

# Convert to Pandas DataFrame
df = pd.DataFrame({
    'filepaths': filepaths,
    'labels': labels
})

# Show dataset info
print(f"Total images: {len(df)}")
print("\nClass distribution:")
print(df['labels'].value_counts())
# Out:
# Total images: 10982
#
# Class distribution:
# labels
# tujuh lima ribu    1550
# lima puluh ribu    1415
# sepuluh ribu       1394
# dua ribu           1366
# seratus ribu       1346
# dua puluh ribu     1336
# seribu             1288
# lima ribu          1287
# Name: count, dtype: int64

# %% [markdown]
# ### **DATA SPLITTING**

# %%
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Stratified split to maintain class distribution
train_df, temp_df = train_test_split(
    df, 
    train_size=train_ratio, 
    stratify=df['labels'],
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df, 
    train_size=val_ratio/(val_ratio + test_ratio), 
    stratify=temp_df['labels'],
    random_state=42
)

print(f"\nTraining set size   : {len(train_df)}")
print(f"Validation set size : {len(val_df)}")
print(f"Testing set size    : {len(test_df)}")
# Out:
# Training set size   : 8785
# Validation set size : 1098
# Testing set size    : 1099

# %% [markdown]
# ### **DATA GENERATORS**

# %%
img_size = (224, 224)
batch_size = 32
img_shape = (*img_size, 3)

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30, 
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation and testing (no augmentation)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators
train_gen = train_datagen.flow_from_dataframe(
    train_df,
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
    seed=42
)

valid_gen = test_datagen.flow_from_dataframe(
    val_df,
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df,
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=False
)

# Get class information
class_names = list(train_gen.class_indices.keys())
num_classes = len(class_names)
print("\nClasses:", class_names)
# Out:
# Found 8785 validated image filenames belonging to 8 classes.
# Found 1098 validated image filenames belonging to 8 classes.
# Found 1099 validated image filenames belonging to 8 classes.
#
# Classes: ['dua puluh ribu', 'dua ribu', 'lima puluh ribu', 'lima ribu', 'sepuluh ribu', 'seratus ribu', 'seribu', 'tujuh lima ribu']

# %% [markdown]
# ### **MODEL ARCHITECTURE**

# %%
modelnamefile = "best_model_xception.h5"
finalnamefile = "final_model_xception.h5"

def create_model():
    base_model = Xception(
        include_top=False,
        weights='imagenet',
        input_shape=img_shape,
        pooling='avg'
    )
    base_model.trainable = False  # Freeze base model
    
    model = models.Sequential([
        base_model,
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

model = create_model()
# Out:
# WARNING:tensorflow:From c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 21388080 (81.59 MB)
# Trainable params: 526600 (2.01 MB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %% [markdown]
# ### **MODEL COMPILE AND TRAINING**

# %%
save_dir = r'C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL2 - XCeption'

# %%
import pickle

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint(
        filepath=os.path.join(save_dir, modelnamefile),
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
    # ReduceLROnPlateau(
    #     monitor='val_loss',
    #     factor=0.5,           # Reduce the learning rate by half
    #     patience=3,           # Wait for 3 epochs with no improvement
    #     min_lr=1e-6,          # Don't reduce below this learning rate
    #     verbose=1
    # )
]

# Training
epochs = 25
history = model.fit(
    train_gen,
    epochs=epochs,
    validation_data=valid_gen,
    callbacks=callbacks,
    verbose=1
)

# Save the training history
with open(os.path.join(save_dir, 'training-history.pkl'), 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# Epoch 1/25
# WARNING:tensorflow:From c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 275/275 [==============================] - ETA: 0s - loss: 1.6789 - accuracy: 0.3704
# Epoch 1: val_accuracy improved from -inf to 0.56557, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 275/275 [==============================] - 1119s 4s/step - loss: 1.6789 - accuracy: 0.3704 - val_loss: 1.2449 - val_accuracy: 0.5656
# Epoch 2/25
# 275/275 [==============================] - ETA: 0s - loss: 1.3486 - accuracy: 0.4996
# Epoch 2: val_accuracy improved from 0.56557 to 0.64936, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1299s 5s/step - loss: 1.3486 - accuracy: 0.4996 - val_loss: 1.0201 - val_accuracy: 0.6494
# Epoch 3/25
# 275/275 [==============================] - ETA: 0s - loss: 1.2057 - accuracy: 0.5521
# Epoch 3: val_accuracy improved from 0.64936 to 0.66576, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1298s 5s/step - loss: 1.2057 - accuracy: 0.5521 - val_loss: 0.9410 - val_accuracy: 0.6658
# Epoch 4/25
# 275/275 [==============================] - ETA: 0s - loss: 1.1386 - accuracy: 0.5752
# Epoch 4: val_accuracy improved from 0.66576 to 0.66758, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1273s 5s/step - loss: 1.1386 - accuracy: 0.5752 - val_loss: 0.8821 - val_accuracy: 0.6676
# Epoch 5/25
# 275/275 [==============================] - ETA: 0s - loss: 1.0943 - accuracy: 0.5912
# Epoch 5: val_accuracy improved from 0.66758 to 0.70310, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1037s 4s/step - loss: 1.0943 - accuracy: 0.5912 - val_loss: 0.8587 - val_accuracy: 0.7031
# Epoch 6/25
# 275/275 [==============================] - ETA: 0s - loss: 1.0474 - accuracy: 0.6129
# Epoch 6: val_accuracy improved from 0.70310 to 0.72769, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1369s 5s/step - loss: 1.0474 - accuracy: 0.6129 - val_loss: 0.7847 - val_accuracy: 0.7277
# Epoch 7/25
# 275/275 [==============================] - ETA: 0s - loss: 1.0064 - accuracy: 0.6336
# Epoch 7: val_accuracy improved from 0.72769 to 0.73770, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1453s 5s/step - loss: 1.0064 - accuracy: 0.6336 - val_loss: 0.7394 - val_accuracy: 0.7377
# Epoch 8/25
# 275/275 [==============================] - ETA: 0s - loss: 0.9976 - accuracy: 0.6349
# Epoch 8: val_accuracy did not improve from 0.73770
# 275/275 [==============================] - 1426s 5s/step - loss: 0.9976 - accuracy: 0.6349 - val_loss: 0.7464 - val_accuracy: 0.7186
# Epoch 9/25
# 275/275 [==============================] - ETA: 0s - loss: 0.9560 - accuracy: 0.6434
# Epoch 9: val_accuracy did not improve from 0.73770
# 275/275 [==============================] - 1416s 5s/step - loss: 0.9560 - accuracy: 0.6434 - val_loss: 0.7429 - val_accuracy: 0.7259
# Epoch 10/25
# 275/275 [==============================] - ETA: 0s - loss: 0.9438 - accuracy: 0.6486
# Epoch 10: val_accuracy improved from 0.73770 to 0.74681, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1425s 5s/step - loss: 0.9438 - accuracy: 0.6486 - val_loss: 0.7067 - val_accuracy: 0.7468
# Epoch 11/25
# 275/275 [==============================] - ETA: 0s - loss: 0.9212 - accuracy: 0.6582
# Epoch 11: val_accuracy improved from 0.74681 to 0.76321, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1615s 6s/step - loss: 0.9212 - accuracy: 0.6582 - val_loss: 0.6920 - val_accuracy: 0.7632
# Epoch 12/25
# 275/275 [==============================] - ETA: 0s - loss: 0.9185 - accuracy: 0.6589
# Epoch 12: val_accuracy did not improve from 0.76321
# 275/275 [==============================] - 1598s 6s/step - loss: 0.9185 - accuracy: 0.6589 - val_loss: 0.7001 - val_accuracy: 0.7614
# Epoch 13/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8999 - accuracy: 0.6670
# Epoch 13: val_accuracy did not improve from 0.76321
# 275/275 [==============================] - 1606s 6s/step - loss: 0.8999 - accuracy: 0.6670 - val_loss: 0.6756 - val_accuracy: 0.7577
# Epoch 14/25
# 275/275 [==============================] - ETA: 0s - loss: 0.9012 - accuracy: 0.6697
# Epoch 14: val_accuracy improved from 0.76321 to 0.77322, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1470s 5s/step - loss: 0.9012 - accuracy: 0.6697 - val_loss: 0.6210 - val_accuracy: 0.7732
# Epoch 15/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8948 - accuracy: 0.6619
# Epoch 15: val_accuracy improved from 0.77322 to 0.77960, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 989s 4s/step - loss: 0.8948 - accuracy: 0.6619 - val_loss: 0.6075 - val_accuracy: 0.7796
# Epoch 16/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8630 - accuracy: 0.6771
# Epoch 16: val_accuracy improved from 0.77960 to 0.78233, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1273s 5s/step - loss: 0.8630 - accuracy: 0.6771 - val_loss: 0.6227 - val_accuracy: 0.7823
# Epoch 17/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8671 - accuracy: 0.6791
# Epoch 17: val_accuracy did not improve from 0.78233
# 275/275 [==============================] - 1166s 4s/step - loss: 0.8671 - accuracy: 0.6791 - val_loss: 0.6254 - val_accuracy: 0.7723
# Epoch 18/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8574 - accuracy: 0.6777
# Epoch 18: val_accuracy did not improve from 0.78233
# 275/275 [==============================] - 1107s 4s/step - loss: 0.8574 - accuracy: 0.6777 - val_loss: 0.6209 - val_accuracy: 0.7678
# Epoch 19/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8448 - accuracy: 0.6858
# Epoch 19: val_accuracy did not improve from 0.78233
# 275/275 [==============================] - 1666s 6s/step - loss: 0.8448 - accuracy: 0.6858 - val_loss: 0.6159 - val_accuracy: 0.7778
# Epoch 20/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8351 - accuracy: 0.6912
# Epoch 20: val_accuracy improved from 0.78233 to 0.78597, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1117s 4s/step - loss: 0.8351 - accuracy: 0.6912 - val_loss: 0.5828 - val_accuracy: 0.7860
# Epoch 21/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8341 - accuracy: 0.6904
# Epoch 21: val_accuracy did not improve from 0.78597
# 275/275 [==============================] - 1071s 4s/step - loss: 0.8341 - accuracy: 0.6904 - val_loss: 0.5932 - val_accuracy: 0.7842
# Epoch 22/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8229 - accuracy: 0.6936
# Epoch 22: val_accuracy did not improve from 0.78597
# 275/275 [==============================] - 1072s 4s/step - loss: 0.8229 - accuracy: 0.6936 - val_loss: 0.6001 - val_accuracy: 0.7832
# Epoch 23/25
# 275/275 [==============================] - ETA: 0s - loss: 0.8104 - accuracy: 0.7046
# Epoch 23: val_accuracy improved from 0.78597 to 0.80510, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 1068s 4s/step - loss: 0.8104 - accuracy: 0.7046 - val_loss: 0.5613 - val_accuracy: 0.8051
# Epoch 24/25
# 275/275 [==============================] - ETA: 0s - loss: 0.7918 - accuracy: 0.7085
# Epoch 24: val_accuracy improved from 0.80510 to 0.81330, saving model to C:\Users\edwin\OneDrive - Bina Nusantara\PPTI - CAWU 3\Artificial Intelligence\project\KLASIFIKASI_UANG_KERTAS_RUPIAH\MODEL3 - XCeption\best_model_xception.h5
# 275/275 [==============================] - 6650s 24s/step - loss: 0.7918 - accuracy: 0.7085 - val_loss: 0.5570 - val_accuracy: 0.8133
# Epoch 25/25
# 275/275 [==============================] - ETA: 0s - loss: 0.7889 - accuracy: 0.7122
# Epoch 25: val_accuracy did not improve from 0.81330
# 275/275 [==============================] - 993s 4s/step - loss: 0.7889 - accuracy: 0.7122 - val_loss: 0.5468 - val_accuracy: 0.8033

# %% [markdown]
# ### **EVALUATING AND VISUALIZATION**

# %%
import pickle

# loading training history
with open(os.path.join(save_dir, 'training-history.pkl'), 'rb') as f:
    history_dict = pickle.load(f)

class FakeHistory:
    def __init__(self, history):
        self.history = history

history = FakeHistory(history_dict)

# Load best model
model = models.load_model(os.path.join(save_dir, modelnamefile))

# Evaluate on test set
test_loss, test_acc = model.evaluate(test_gen, verbose=0)
# print(f"\nTest Accuracy: {test_acc:.4f}")
# print(f"Test Loss: {test_loss:.4f}")
print("\033[1;32m" + f"Test Accuracy: {test_acc:.4f}" + "\033[0m")
print("\033[1;32m" + f"Test Loss: {test_loss:.4f}" + "\033[0m")

# Plot training history
def plot_history(history):
    plt.figure(figsize=(14, 6))
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)
    
    # Find best epochs
    best_acc_epoch = np.argmax(val_acc) + 1
    best_loss_epoch = np.argmin(val_loss) + 1
    best_acc_value = val_acc[best_acc_epoch - 1]
    best_loss_value = val_loss[best_loss_epoch - 1]
    
    train_color = '#1f77b4'   # Blue
    val_color = '#ff7f0e'     # Orange
    best_marker_color = '#d62728'  # Red
    
    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'o-', color=train_color, label='Train Accuracy', alpha=0.7)
    plt.plot(epochs, val_acc, 's-', color=val_color, label='Validation Accuracy', alpha=0.7)
    
    # Mark best accuracy epoch
    plt.scatter(best_acc_epoch, best_acc_value, s=200, 
                marker='*', color=best_marker_color, 
                zorder=10, edgecolor='black', 
                label=f'Best Val Acc: {best_acc_value:.2%}\n(Epoch {best_acc_epoch})')
    
    plt.title('Training and Validation Accuracy', fontsize=14, pad=10)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend(loc='lower right', frameon=True, facecolor='white')
    
    # Add epoch markers
    plt.xticks(epochs)
    plt.gca().xaxis.grid(True, which='major', linestyle=':', alpha=0.4)
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'o-', color=train_color, label='Train Loss', alpha=0.7)
    plt.plot(epochs, val_loss, 's-', color=val_color, label='Validation Loss', alpha=0.7)
    
    # Mark best loss epoch
    plt.scatter(best_loss_epoch, best_loss_value, s=200,
                marker='*', color=best_marker_color,
                zorder=10, edgecolor='black',
                label=f'Best Val Loss: {best_loss_value:.4f}\n(Epoch {best_loss_epoch})')
    
    plt.title('Training and Validation Loss', fontsize=14, pad=10)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend(loc='upper right', frameon=True, facecolor='white')
    
    # Add epoch markers
    plt.xticks(epochs)
    plt.gca().xaxis.grid(True, which='major', linestyle=':', alpha=0.4)
    
    # Add overall title
    plt.suptitle('Model Training History with Best Epoch Markers', fontsize=16, y=0.98)
    
    plt.tight_layout()
    plt.show()
    
    # Return best epochs for reference
    return best_acc_epoch, best_loss_epoch

best_acc_epoch, best_loss_epoch = plot_history(history)
print(f"Best validation accuracy at epoch {best_acc_epoch}")
print(f"Best validation loss at epoch {best_loss_epoch}")


# DATA FOR CONFUSSION MATRIX AND CLASSIFICATION REPORT
y_pred = model.predict(test_gen)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_gen.classes
# Out:
# WARNING:tensorflow:From c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# Test Accuracy: 0.7898
# Test Loss: 0.5842
# Best validation accuracy at epoch 24
# Best validation loss at epoch 25
# 35/35 [==============================] - 96s 3s/step

# %% [markdown]
# #### EVALUATE - CONFUSSION MATRIX DIAGRAM

# %%
def plot_enhanced_confusion_matrix(y_true, y_pred, classes, 
                          title='Confusion Matrix', 
                          cmap='Greens', 
                          normalize=False, 
                          figsize=(12, 10)):
    """
    Enhanced confusion matrix visualization with dual annotations and diagnostics
    
    Parameters:
    y_true : array-like
        True labels
    y_pred : array-like
        Predicted labels
    classes : list
        Class names
    title : str, optional
        Title for the plot
    cmap : str, optional
        Matplotlib colormap
    normalize : bool, optional
        Whether to normalize the matrix
    figsize : tuple, optional
        Figure size
    """
    # Create figure
    fig = plt.figure(figsize=figsize)
    
    # Calculate confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Normalize if requested
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        fmt = '.2f'
        vmax = 1.0
    else:
        fmt = 'd'
        vmax = cm.max()
    
    # Create custom annotation matrix
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            if normalize:
                annot[i, j] = f"{cm[i, j]:.1%}\n({confusion_matrix(y_true, y_pred)[i, j]})"
            else:
                annot[i, j] = f"{cm[i, j]}\n({cm[i, j]/cm.sum(axis=1)[i]:.1%})"
    
    # Create main heatmap
    ax = plt.subplot()
    sns.heatmap(cm, annot=annot, fmt='', 
                cmap=cmap, vmin=0, vmax=vmax,
                cbar=True, linewidths=0.5, linecolor='gray',
                xticklabels=classes, yticklabels=classes,
                ax=ax)
    
    # Add labels
    ax.set_xlabel('Predicted Label', fontsize=12, labelpad=10)
    ax.set_ylabel('True Label', fontsize=12, labelpad=10)
    
    # Rotate and align x labels
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    
    # Add title
    accuracy = np.trace(cm) / np.sum(cm)
    ax.set_title(f"{title}\nOverall Accuracy: {accuracy:.2%}", fontsize=14, pad=20)
    
    # Highlight maximum off-diagonal values
    for i in range(nrows):
        for j in range(ncols):
            if i != j and cm[i, j] > 0.7 * cm.max():
                ax.text(j + 0.5, i + 0.5, annot[i, j], 
                        ha="center", va="center", 
                        fontweight='bold', color='red',
                        bbox=dict(boxstyle="round,pad=0.3", fc='yellow', ec="black", alpha=0.5))
    
    # Add class distribution information
    plt.figtext(0.5, -0.05, 
                f"True Class Distribution: {dict(zip(classes, np.sum(cm, axis=1)))}",
                ha="center", fontsize=10, color='#555555')
    plt.figtext(0.5, -0.08, 
                f"Predicted Class Distribution: {dict(zip(classes, np.sum(cm, axis=0)))}",
                ha="center", fontsize=10, color='#555555')
    
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.15)  # Make space for distribution info
    plt.show()

# plot_confusion_matrix(y_true, y_pred_classes, class_names)
plot_enhanced_confusion_matrix(y_true, y_pred_classes, class_names)

# %% [markdown]
# #### EVALUATE - PRINT CLASSIFICATION REPORT

# %%
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#  dua puluh ribu       0.79      0.69      0.74       133
#        dua ribu       0.81      0.88      0.85       137
# lima puluh ribu       0.68      0.74      0.71       142
#       lima ribu       0.78      0.90      0.84       129
#    sepuluh ribu       0.74      0.60      0.66       140
#    seratus ribu       0.82      0.84      0.83       134
#          seribu       0.77      0.74      0.75       129
# tujuh lima ribu       0.92      0.92      0.92       155
#
#        accuracy                           0.79      1099
#       macro avg       0.79      0.79      0.79      1099
#    weighted avg       0.79      0.79      0.79      1099

# %% [markdown]
# #### EVALUATE - PREDICT IMAGE

# %%
from tensorflow.keras.preprocessing import image

model = models.load_model(os.path.join(save_dir, modelnamefile))

img_path = r"../datasets/lima ribu/IMG20201220092601-removebg-preview.pnglantai.jpg"
img = image.load_img(img_path, target_size=(224, 224))
img_arr = image.img_to_array(img)
img_arr = np.expand_dims(img_arr, axis=0)
img_arr = img_arr / 255.0

# %%
prediction = model.predict(img_arr)
predicted_class = np.argmax(prediction, axis=1)
print("Predicted class index:", predicted_class)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted class index: [3]

# %%
class_indices = test_gen.class_indices
labels = dict((v, k) for k, v in class_indices.items())
print("Predicted label:", labels[predicted_class[0]])
# Out:
# Predicted label: lima ribu

# %% [markdown]
# #### EVALUATE - MISCLASSIFIED CLASSES AND IMAGES

# %%
def plot_most_misclassified_classes(y_true, y_pred, class_names, top_n=10, figsize=(8, 4)):
    """
    Plots a horizontal bar chart of classes with the highest misclassification rates
    
    Parameters:
    y_true : array-like
        True labels
    y_pred : array-like
        Predicted labels
    class_names : list
        Class names
    top_n : int, optional
        Number of top classes to show
    figsize : tuple, optional
        Figure size
    """
    # Calculate misclassification counts per class
    misclassified_counts = {}
    for true_label, pred_label in zip(y_true, y_pred):
        if true_label != pred_label:
            class_name = class_names[true_label]
            misclassified_counts[class_name] = misclassified_counts.get(class_name, 0) + 1
    
    # Convert to sorted list
    sorted_misclassified = sorted(misclassified_counts.items(), 
                                  key=lambda x: x[1], 
                                  reverse=True)[:top_n]
    
    # Extract data for plotting
    classes = [item[0] for item in sorted_misclassified]
    counts = [item[1] for item in sorted_misclassified]
    
    # Calculate misclassification rates
    class_counts = np.bincount(y_true)
    rates = [count / class_counts[class_names.index(cls)] for cls, count in sorted_misclassified]
    
    # Create figure
    plt.figure(figsize=figsize)
    ax = plt.subplot()
    
    # Create horizontal bars
    y_pos = np.arange(len(classes))
    bars = ax.barh(y_pos, counts, color='#e74c3c', alpha=0.8)
    
    # Add count labels
    for i, bar in enumerate(bars):
        width = bar.get_width()
        ax.text(width + max(counts)*0.01, bar.get_y() + bar.get_height()/2,
                f'{counts[i]} ({rates[i]:.1%})',
                va='center', ha='left', fontsize=10)
    
    # Add rate labels on the left
    for i, rate in enumerate(rates):
        ax.text(0.01, i, f'{rate:.1%}', 
                va='center', ha='left', color='white', fontweight='bold')
    
    # Customize plot
    ax.set_yticks(y_pos)
    ax.set_yticklabels(classes, fontsize=12)
    ax.invert_yaxis()  # Highest at top
    ax.set_xlabel('Misclassification Count', fontsize=12)
    ax.set_title(f'Top {top_n} Most Misclassified Classes', fontsize=16, pad=20)
    
    # Add grid
    ax.xaxis.grid(True, linestyle='--', alpha=0.3)
    
    # Add insights
    total_misclassified = sum(misclassified_counts.values())
    plt.figtext(0.5, 0.01, 
                f"Total misclassifications: {total_misclassified} ({total_misclassified/len(y_true):.1%} of all samples)",
                ha="center", fontsize=12, color='#7f8c8d')
    
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.20)
    plt.show()

def show_misclassified_image_samples(test_gen, y_true, y_pred, class_names, 
                                    num_samples=12, figsize=(15, 12), 
                                    seed=42):
    """
    Displays a grid of misclassified images with true and predicted labels
    
    Parameters:
    test_gen : ImageDataGenerator
        Test data generator
    y_true : array-like
        True labels
    y_pred : array-like
        Predicted labels
    class_names : list
        Class names
    num_samples : int, optional
        Number of samples to display
    figsize : tuple, optional
        Figure size
    seed : int, optional
        Random seed for reproducibility
    """
    # Get misclassified indices
    misclassified_indices = np.where(y_true != y_pred)[0]
    
    # Handle case with no misclassifications
    if len(misclassified_indices) == 0:
        print("No misclassifications found!")
        return
    
    # Randomly select samples
    np.random.seed(seed)
    selected_indices = np.random.choice(misclassified_indices, 
                                       size=min(num_samples, len(misclassified_indices)), 
                                       replace=False)
    
    # Create figure
    plt.figure(figsize=figsize)
    
    # Calculate grid size
    cols = 4
    rows = int(np.ceil(num_samples / cols))
    
    for i, idx in enumerate(selected_indices):
        # Get image and labels
        img_path = test_gen.filepaths[idx]
        img = plt.imread(img_path)
        true_label = class_names[y_true[idx]]
        pred_label = class_names[y_pred[idx]]
        
        # Create subplot
        ax = plt.subplot(rows, cols, i+1)
        
        # Show image
        plt.imshow(img)
        plt.axis('off')
        
        # Create title with colored labels
        title = f"True: {true_label}\nPred: {pred_label}"
        plt.title(title, fontsize=12, color='#e74c3c' if true_label != pred_label else '#2ecc71')
        
        # Add red border to misclassified images
        for spine in ax.spines.values():
            spine.set_edgecolor('#e74c3c')
            spine.set_linewidth(2)
    
    # Add overall title
    plt.suptitle(f"Misclassified Samples ({len(selected_indices)} shown)", 
                 fontsize=16, y=0.98, color='#c0392b')
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()


# Plot most misclassified classes
plot_most_misclassified_classes(y_true, y_pred_classes, class_names, top_n=5)

# Show misclassified image samples
show_misclassified_image_samples(test_gen, y_true, y_pred_classes, class_names, 
                                num_samples=12, seed=42)

# %% [markdown]
# ### **SAVE MISCLASSIFIED SAMPLES**

# %%
def save_misclassified_samples(test_gen, y_true, y_pred_classes, class_names, save_dir):
    """Save misclassified images for manual review"""
    misclassified_indices = np.where(y_true != y_pred_classes)[0]
    
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    for i, idx in enumerate(misclassified_indices[:20]):  # Save first 20
        # Get image and paths
        img_path = test_gen.filepaths[idx]
        img = plt.imread(img_path)
        
        # Get labels
        true_label = class_names[y_true[idx]]
        pred_label = class_names[y_pred_classes[idx]]
        
        # Create figure
        plt.figure(figsize=(6, 6))
        plt.imshow(img)
        plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=12)
        plt.axis('off')
        
        # Save to file
        save_path = os.path.join(save_dir, f"misclassified_{i+1}.png")
        plt.savefig(save_path, bbox_inches='tight', dpi=100)
        plt.close()
    
    print(f"Saved {min(20, len(misclassified_indices))} misclassified samples to {save_dir}")

# Save misclassified samples
save_misclassified_samples(
    test_gen, 
    y_true, 
    y_pred_classes,     
    class_names,
    os.path.join(save_dir, 'misclassified_samples')
)

# %% [markdown]
# ### **SAVE FINAL MODEL**

# %%
model.save(os.path.join(save_dir, finalnamefile))
print("Model saved successfully!")

# Save class mapping
class_mapping = {v: k for k, v in train_gen.class_indices.items()}
np.save(os.path.join(save_dir, 'class_mapping.npy'), class_mapping)
print("Class mapping saved.")
# Out:
# c:\Users\edwin\anaconda3\envs\ai-klasifikasi-mata-uang-rupiah\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved successfully!
# Class mapping saved.
